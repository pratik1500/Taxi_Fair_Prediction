# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

# %%
'''Fetching cleaned dataset'''
df = pd.read_csv('D:\Projects\coditas_project\dataset\data_cleaned.csv')
df.head()
# Out:
#       index                            key  fare_amount      pickup_datetime  \
# 0  24238194    2015-05-07 19:52:06.0000003          7.5  2015-05-07 19:52:06
# 1  27835199    2009-07-17 20:04:56.0000002          7.7  2009-07-17 20:04:56
# 2  44984355   2009-08-24 21:45:00.00000061         12.9  2009-08-24 21:45:00
# 3  25894730    2009-06-26 08:22:21.0000001          5.3  2009-06-26 08:22:21
# 4  17610152  2014-08-28 17:47:00.000000188         16.0  2014-08-28 17:47:00
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.999817        40.738354         -73.999512         40.723217
# 1        -73.994355        40.728225         -73.994710         40.750325
# 2        -74.005043        40.740770         -73.962565         40.772647
# 3        -73.976124        40.790844         -73.965316         40.803349
# 4        -73.925023        40.744085         -73.973082         40.761247
#
# ...

# %%
'''Droping the unuseful columns'''
drop_columns=['key','pickup_datetime','pickup_date', 'index']
df_after_drop = df.drop(drop_columns,axis=1)

# %%
df_after_drop.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  is_pickup_JFK  is_dropoff_JFK  \
# 0         40.723217                1              0               0
# 1         40.750325                1              0               0
# 2         40.772647                1              0               0
# 3         40.803349                3              0               0
# 4         40.761247                5              0               0
#
#    is_pickup_LGA  is_dropoff_LGA  is_pickup_EWR  is_dropoff_EWR  pickup_day  \
# ...

# %%
x=df_after_drop.drop(['fare_amount'],axis=1) # Selecting all non-target variables
y = df_after_drop['fare_amount'] # Target Variable

# %%
''''split data into train and validation data'''
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2) # Spliting data into train and test
print("Number of records in training data ",X_train.shape[0])
print("Number of records in validation data ",X_test.shape[0])
# Out:
# Number of records in training data  152676
# Number of records in validation data  38169

# %% [markdown]
# Analysing the result using rmse
# Which is root mean square error

# %%
'''Training a simple linear regression model'''
lm = LinearRegression() # Defining linear regression model
lm.fit(X_train,y_train) # Fit on the training dataset
y_pred=lm.predict(X_test) # Predicting test data 
lm_rmse=np.sqrt(mean_squared_error(y_pred, y_test)) 
print("RMSE for Linear Regression is ",lm_rmse)
# Out:
# RMSE for Linear Regression is  5.472961043780592

# %% [markdown]
# Random Forest

# %%
'''Traing the Radom Forest Regressor'''
from sklearn.ensemble import RandomForestRegressor

clf = RandomForestRegressor(max_depth=140,max_features='auto',min_samples_leaf=10,n_estimators=400) # Defining Regression model after hyperparameter tunning
clf.fit(X_train, y_train) # Training the model
y_pred = clf.predict(X_test) # Predicting on the prediction dataset 
rf_rmse = np.sqrt(mean_squared_error(y_pred, y_test)) # Calculating rmse ===> Root mean squared error
print("RMSE FOR RANDOM FOREST IS",rf_rmse)
# Out:
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\ensemble\_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# RMSE FOR RANDOM FOREST IS 4.588593055306849
